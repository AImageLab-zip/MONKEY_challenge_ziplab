# %% [markdown]
# # Understanding the MONKEY Challenge Dataset

# %%
#!pip install seaborn openpyxl

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("ggplot")
# ignore warnings
import warnings

warnings.filterwarnings("ignore")

# %% [markdown]
# ## Dataset Information
# | Field                | Description                                                                                       | Type                            |
# |----------------------|---------------------------------------------------------------------------------------------------|---------------------------------|
# | Slide ID            | Label of each slide. For the tif files, the name extends from the ID to also include the staining and scanning setting, e.g., A_P00001_PAS_CPG | string                         |
# | Lab                 | The pathology institution that the cases were collected at (also indicated with a letter in the file name) | string [Radboud, Utrecht, Vienna, Mayo] |
# | Diagnosis           | Final Banff diagnosis of the case                                                                 | string (multi word)            |
# | CD3CD20_IHC_quality | Quality of the CD3CD20 IHC staining (brown, lymphocytes)                                          | string (multi word)            |
# | PU.1_IHC_quality    | Quality of the PU.1 IHC staining (red, monocytes)                                                 | string (multi word)            |
# | IR_CPG-IHC          | Quality of the image registration between the CPG profile scans and the IHC scans                 | string (multi word)            |
# | IR_CPG-Diagnostic   | Quality of the image registration between the CPG profile and the Diagnostic profile scans         | string (multi word)            |
# | IR_CPG-Original     | Quality of the image registration between the CPG profile and the Original scan profile scans      | string (multi word)            |
# | Nb_lymphocytes      | Number of lymphocytes annotated on slide                                                          | int                             |
# | Nb_monocytes        | Number of monocytes annotated on slide                                                            | int                             |
# | Nb_rois             | Number of ROIs annotated on slide                                                                 | int                             |

# %% [markdown]
# #### Annotation data:
# - XML file containing the coordinates of the annotations and the ROI polygon at a spacing of 0.24um/pixels can be loaded and viewed using ASAP.
# - JSON file in the same format as the output.
# - Binary mask of the ROIs in TIFF file format.
#
# #### Context data:
#
# - Quality score for each IHC slide
# - Quality of the image registration (all are registered to the PAS stain with the CPG profile)
# - Institution from which the biopsy was taken (A, B, C, D)
# - Final biopsy diagnosis to give participants an overview of the distribution of different morphologies with the categories:
#   - insufficient clues for rejection (normal)
#   - ABMR (antibody-mediated rejection)
#   - TCMR (T-cell mediated rejection)
#   - mixed (ABMR+TCMR)
#   - borderline
#   - chronic damage (IFTA)
#   - other (BK virus nephropathy, necrosis).

# %%
# !pip install openpyxl

# %%
data = pd.read_excel("context-information.xlsx", index_col=0)
data.head()
# Out:
#     Slide ID      Lab                                          Diagnosis  \
# 1  A_P000001  Radboud                                           TCMR 2B
# 2  A_P000002  Radboud  Borderline rejection (Mild ptc and focally sus...
# 3  A_P000003  Radboud                 TCMR IB (Severe ptc and tubulitis)
# 4  A_P000004  Radboud                                            TCMR 2A
# 5  A_P000005  Radboud                                            TCMR 2A
#
#   CD3CD20_IHC_quality                                   PU.1_IHC_quality  \
# 1               Good   Acceptable, strong PU1 intenisty with also bac...
# 2               Good   Acceptable, strong PU1 intenisty with also bac...
# 3               Good                        Good, moderate PU1 intensity
# 4               Good                                                Good
# 5               Good                                                Good
#
#   IR_CPG-IHC IR_CPG-Diagnostic IR_CPG-Original  Nb_lymphocytes  Nb_monocytes  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 81 entries, 1 to 89
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Slide ID             81 non-null     object
#  1   Lab                  81 non-null     object
#  2   Diagnosis            81 non-null     object
#  3   CD3CD20_IHC_quality  81 non-null     object
#  4   PU.1_IHC_quality     81 non-null     object
#  5   IR_CPG-IHC           81 non-null     object
#  6   IR_CPG-Diagnostic    81 non-null     object
#  7   IR_CPG-Original      81 non-null     object
#  8   Nb_lymphocytes       81 non-null     int64
#  9   Nb_monocytes         81 non-null     int64
#  10  Nb_rois              81 non-null     int64
# dtypes: int64(3), object(8)
# memory usage: 7.6+ KB

# %% [markdown]
# We have 81 cases as indicated in the challenge website for dataset details, also no null values in metadata.
# NOTE: "x" indicates that there is no such slide present in the dataset.

# %% [markdown]
# ## E.D.A.

# %% [markdown]
# Slide IDs

# %%
data["Slide ID"].value_counts().max()  # we have unique values id for rows
# Out:
# 1

# %% [markdown]
# Lab

# %%
data["Lab"].value_counts().plot(kind="bar")
plt.grid(axis="x")
plt.title("Lab Distribution in the training data")
plt.show()

# %% [markdown]
# Diagnosis

# %%
# plot the diagnosis column relative to dataset size
plt.figure(figsize=(12, 6))
sns.countplot(
    data["Diagnosis"],
    label="Count",
    palette="tab10",
    order=data["Diagnosis"].value_counts().index,
)
plt.grid(True)
# set x ticks to every numnbr of data points
plt.xticks(np.arange(0, max(data["Diagnosis"].value_counts() + 1), step=1))
plt.show()

# %% [markdown]
# Studying the distribution of the inflammatory cells based on the diagnosis.

# %%
data.groupby(["Diagnosis"])[["Nb_lymphocytes", "Nb_monocytes"]].mean().sort_values(
    by=["Nb_lymphocytes", "Nb_monocytes"]
).plot(kind="barh", figsize=(14, 8))
plt.show()

# %%
# Create subplots
fig, ax = plt.subplots(1, 2, figsize=(14, 6))

# Plot lymphocytes and monocytes distribution in the first subplot
sns.kdeplot(data=data, x="Nb_lymphocytes", fill=True, color="red", ax=ax[0])
sns.kdeplot(data=data, x="Nb_monocytes", fill=True, color="blue", ax=ax[0])

# Plot total immune cells distribution in the second subplot
sns.kdeplot(data=data, x="Total_nb_of_cells", fill=True, color="purple", ax=ax[1])

# Add legends and labels
ax[0].legend(["Lymphocytes", "Monocytes"])
ax[0].set_title("Distribution of Lymphocytes and Monocytes")
ax[0].set_xlabel("Cell Count")
ax[0].set_ylabel("Density")

ax[1].legend(["Total Immune Cells"])
ax[1].set_title("Distribution of Total Immune Cells")
ax[1].set_xlabel("Total Cell Count")
ax[1].set_ylabel("Density")

# Add grid for both subplots
for a in ax:
    a.grid(True)

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# Slide types presence

# %%
# barplot of the columns
slide_types_quality = ["IR_CPG-IHC", "IR_CPG-Diagnostic", "IR_CPG-Original"]
name_dict_quality = [
    "CPG to IHC aligment quality",
    "CPG to Diagnostic aligment quality",
    "CPG to Original aligment quality",
]
data[slide_types_quality]
# Out:
#    IR_CPG-IHC IR_CPG-Diagnostic IR_CPG-Original
# 1        Good                 x               x
# 2        Good                 x               x
# 3        Good                 x               x
# 4        Good                 x               x
# 5        Good                 x               x
# ..        ...               ...             ...
# 85       Good              Good            Good
# 86       Good              Good            Good
# 87       Good              Good            Good
# 88       Good              Good            Good
# 89       Good              Good            Good
#
# [81 rows x 3 columns]

# %%
data[["IR_CPG-IHC", "IR_CPG-Diagnostic", "IR_CPG-Original"]].replace(
    "x", "Not available", inplace=True
)

# %%
# make 3 subplots for ["IR_CPG-IHC","IR_CPG-Diagnostic","IR_CPG-Original"] barplots
fig, axes = plt.subplots(1, 3, figsize=(20, 5))
fig.suptitle("Alignment quality of the slides")
for i, slide_type in enumerate(slide_types_quality):
    data[slide_type].value_counts(normalize=True).plot(kind="bar", ax=axes[i])
    axes[i].set_title(f"{slide_type} quality")
    axes[i].grid(axis="x")
    axes[i].set_ylabel("Percentage")
    axes[i].set_xlabel("")
    axes[i].set_title(f"{name_dict_quality[i]}")
plt.show()

# %%
sns.pairplot(
    data,
    diag_kind="kde",
    kind="scatter",
    palette="husl",
    markers="o",
    height=3,
    aspect=1,
)
plt.show()

# %%
# correlation matrix
num_cols = data.select_dtypes(include=[np.number]).columns
corr = data[num_cols].corr()
plt.figure(figsize=(10, 10))
sns.heatmap(
    corr,
    annot=True,
    cmap="viridis",
    fmt=".2f",
    square=True,
    cbar=True,
    annot_kws={"size": 10},
)
plt.show()

# %% [markdown]
# Of course the number of lymphocytes and monocytes present in the slide are correlated, along with the numbers of R.O.Is

# %%
data.iloc[:, -3:].describe()
# Out:
#        Nb_lymphocytes  Nb_monocytes    Nb_rois
# count       81.000000     81.000000  81.000000
# mean       729.641975    386.000000   2.024691
# std        679.426363    359.883974   0.836291
# min          4.000000     47.000000   1.000000
# 25%        209.000000    162.000000   2.000000
# 50%        512.000000    251.000000   2.000000
# 75%       1063.000000    423.000000   2.000000
# max       3257.000000   1903.000000   5.000000

# %% [markdown]
# We have an average number of 2 R.O.Is per slide, with a maximum of 5.
# The average number of annotated lymphocytes is almost 730 and the average annotated for the monocytes is 386.
# Outliers are present.

# %%
data.iloc[:, -3:].mean().plot(kind="bar")
plt.title("Mean count of lymphocytes, monocytes and R.O.I.s in the slides")
plt.show()

# %% [markdown]
# Slide Quality

# %% [markdown]
# Lymphocytes staining quality

# %%
data["CD3CD20_IHC_quality"].value_counts(normalize=True).sort_values().plot(kind="barh")
plt.title("IHC lymphocytes staining quality distribution in the training data")
plt.grid(axis="y")
plt.show()

# %% [markdown]
# Monocytes staining quality

# %%
data["PU.1_IHC_quality"].value_counts(normalize=True).sort_values().plot(kind="barh")
plt.title("IHC monocytes staining quality distribution in the training data")
plt.show()

# %% [markdown]
# Image registration quality

# %% [markdown]
# IHC to CPG registrations quality -> this means the "goodness of annotations?"

# %%
data["IR_CPG-IHC"].value_counts(normalize=True).sort_values().plot(kind="barh")
plt.title("IHC to CPG scan registration quality distribution in the training data")
plt.grid(axis="y")
plt.show()

# %% [markdown]
# CPG to Diagnostic WSI registration quality

# %%
# substitute "x" with "Not available" for IR_CPG-Diagnostic
data["IR_CPG-Diagnostic"].replace("x", "Not available", inplace=True)
data["IR_CPG-Diagnostic"].value_counts(normalize=True).sort_values().plot(kind="barh")
plt.title(
    "CPG to Diagnostic scan registration quality distribution in the training data"
)
plt.grid(axis="y")
plt.show()

# %% [markdown]
# CPG to Original WSI registration quality

# %%
# substitute "x" with "Not available" for IR_CPG-Diagnostic
data["IR_CPG-Original"].replace("x", "Not available", inplace=True)
data["IR_CPG-Original"].value_counts(normalize=True).sort_values().plot(kind="barh")
plt.title("CPG to Orginal scan registration quality distribution in the training data")
plt.grid(axis="y")
plt.show()
